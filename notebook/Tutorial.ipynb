# %% [markdown]
# # NEWS SCRAPER TUTORIAL
#
# ___
#
# In this tutorial we will see how to parse the content from a website in order to pulling out some information. The website that we will use is http://www.uraniabasket.it/news; it is the website of the Urania Basket, a basketball team from Milan.
#
# The information that we want to pull out from the news page are:
# 1. Title
# 2. date of publication
# 3. Short summary
# 4. URL of the thumbnail (if any)
# 5. URL of the complete news
#
# Required libraries:
# 1. beautifulsoup4
# 4. requests
# 5. regex
# 6. pandas
#
# __beautifulsoup4__ is a library that makes it easy to scrape information from web pages. It sits atop an HTML or XML parser, providing Pythonic idioms for iterating, searching, and modifying the parse tree.
#
# __requests__ allows us to send the HTTP requests to web-server using python. (HTTP messages consist of requests from client to server and responses from server to client.)

# %%
# !pip install beautifulsoup4
# !pip install requests
# !pip install pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.7/site-packages (from beautifulsoup4) (2.0.1)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.7/site-packages (4.5.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.7/site-packages (1.0.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.18.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %% [markdown]
# Some notes on jhtml:
# 1. `<tag>...</tag>` represents a tag. Tags can be the specification of a bold heading an italic text and so on.
# 2. when we have key='a' it means that we have an anchor tag which contains a link. The link specified by 'href'.

# %%
import bs4
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import sys

# %%
print('Python version: {}'.format(sys.version))
print('Beautiful Soup version : {}'.format(bs4.__version__))
print('Requests version: {}'.format(requests.__version__))
print('Pandas version : {}'.format(pd.__version__))
# Out:
# Python version: 3.7.7 (default, Mar 23 2020, 17:31:31)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Beautiful Soup version : 4.9.1
# Requests version: 2.24.0
# Pandas version : 1.0.5

# %% [markdown]
# We can pass to BeautifulSoup an html file or the link to the web page.

# %%
# Get the source code. The get method will return a response object.
# With the '.text' we obtain the source code.
url = 'http://www.uraniabasket.it/news'
source = requests.get(url).text
soup = BeautifulSoup(source, 'lxml')

# %%
# We can format the source code with the prettify method.
print(soup.prettify())
# Out:
# <!-- w -->
# <!DOCTYPE html>
# <html>
#  <!--
#     _______________  ____    _________
#     __  ___/__  /_ \/ /_ |  / /___  _/
#     _____ \__  / __  /__ | / / __  /
#     ____/ /_  /___  / __ |/ / __/ /
#     /____/ /_____/_/  _____/  /___/
# -->
#  <head>
#   <title>
#   </title>
#   <meta content="" name="description"/>
#   <link href="" rel="icon" type="image/png"/>
#   <meta content="width=device-width, user-scalable=no, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0" name="viewport"/>
#   <!-- Bootstrap -->
#   <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/bxslider/4.2.5/jquery.bxslider.css" rel="stylesheet"/>
#   <link href="https://cdn.jsdelivr.net/jquery.mcustomscrollbar/3.1.5/jquery.mCustomScrollbar.min.css" media="screen" rel="stylesheet"/>
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/css/screen.css" media="screen" rel="stylesheet"/>
#   <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#   <!--[if lt IE 9]>
#         <script src="//www.slyvi.com/assets/js/html5shiv.js"></script>
#         <script src="//www.slyvi.com/assets/js/respond.min.js"></script>
#     <![endif]-->
#   <meta content="232846060162720" property="fb:app_id"/>
#   <meta content="Urania Basket" property="og:title"/>
#   <meta content="" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="http://www.uraniabasket.it/news" property="og:url"/>
#   <meta content="https://slyvi-tlogos.s3.amazonaws.com/r9750593736_tl1961376069377_180066997461_1563399044688186.jpg" property="og:image"/>
#   <meta content="Urania Basket" property="og:site_name"/>
#   <style type="text/css">
#    #navlnk {
# 												position:fixed !important; position:absolute;
# 												right:3px;top:3px;top: expression(3+(a=document.body.scrollTop)+'px');
# 												padding:4px 7px 4px 20px;background:#111 url(images/minicons/n/tp_dashboard.png) 4px center no-repeat;color:#fff;font-size:11px;cursor:pointer;-moz-border-radius:3px;-webkit-border-radius:3px;border-radius:3px
# 											}
#   </style>
#   <script type="text/javascript">
#    var lng = 'it';
# 											var SH = 'www.slyvi.com';
# 											var tp_info = {"name":"Urania Basket","logo":"https:\/\/slyvi-tlogos.s3.amazonaws.com\/r9750593736_tl1961376069377_180066997461_1563399044688186.jpg","fllw":1};
#   </script>
#   <!--[if IE 6]>
# 											<style type="text/css">
# 												#ie6_alert { background: #fff5da; height: 40px; border-bottom: 2px solid #ffd36b; top:0 !important; font-weight: bold; left: 0; right: 0; width: 100%; }
# 												#ie6_alert p { padding: 11px; margin: 0; font-size: 16px; }
# 												#ie6_alert p span { background: url(../images/minicons/exclamation-frame.jpg) no-repeat top left; padding-left: 23px;}
# 											</style>
# 										<![endif]-->
#   <!--[if lt IE 7]>
# 											<script type="text/javascript" src="//www.slyvi.com/js/supersleight-min.js"></script>
# 											<style type="text/css">
# 												body {background-attachment:scroll;}
# 												#userbar {position:absolute;}
# 											</style>
# 										<![endif]-->
#   <link href="https://slyvi-cdn.ams3.digitaloceanspaces.com/assets/css/layoutmanager.css" rel="stylesheet" type="text/css"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.2/jquery.min.js" type="text/javascript">
#   </script>
#   <script src="//www.slyvi.com/js/jquery.team_behavior.js" type="text/javascript">
#   </script>
#   <!-- Matomo -->
#   <script type="text/javascript">
#    var _paq = window._paq || [];
# 				  _paq.push(["trackPageView"]);
# 				  _paq.push(["enableLinkTracking"]);
# 				  (function() {
# 				    var u="https://stats2.slyvi.it/";
# 				    _paq.push(["setTrackerUrl", u+"matomo.php"]);
# 				    _paq.push(["setSiteId", "1961376069377"]);
# 				    var d=document, g=d.createElement("script"), s=d.getElementsByTagName("script")[0];
# 				    g.type="text/javascript"; g.async=true; g.defer=true; g.src=u+"matomo.js"; s.parentNode.insertBefore(g,s);
# 				  })();
#   </script>
#   <!-- End Matomo Code -->
#  </head>
#  <body>
#   <script src="https://slyvi-cdn.ams3.digitaloceanspaces.com/assets/js/cookiechoices.js">
#   </script>
#   <script>
#    // var cookie_policy_page_url = '/cookiepolicy';
# 											var cookie_policy_page_url = '/cookiepolicy';
# 											document.addEventListener('DOMContentLoaded', function(event) {
# 												cookieChoices.showCookieConsentBar('Questo sito o gli strumenti terzi da questo utilizzati si avvalgono di cookie necessari al funzionamento ed utili alle finalità illustrate nella cookie policy. Se vuoi saperne di più o negare il consenso a tutti o ad alcuni cookie, consulta la cookie policy. Chiudendo questo banner acconsenti all\'uso dei cookie.','Chiudi', 'Per saperne di più', cookie_policy_page_url);
# 											});
#   </script>
#   <div class="container">
#    <header>
#     <div style="border-top:15px solid #1C263F; border-bottom:15px solid #d72226;">
#     </div>
#     <div class="bartop">
#      <div class="social-icon">
#       <ul id="social">
#        <li>
#         <a href="http://www.twitter.com/UraniaBasket">
#          <i class="fa fa-twitter">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.facebook.com/UraniaBasket">
#          <i class="fa fa-facebook">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.youtube.com/channel/Urania Basket Milano">
#          <i class="fa fa-youtube-play">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a href="http://www.instagram.com/UraniaBasket">
#          <i class="fa fa-instagram">
#          </i>
#         </a>
#        </li>
#        <!--
#                     <li><a href="#"><i class="fa fa-google-plus"></i></a></li>
#                     <li><a href="#"><i class="fa fa-instagram"></i></a></li>
#                     <li><a href="#"><i class="fa fa-apple"></i></a></li>
#                     <li><a href="#"><i class="fa fa-android"></i></a></li>
#                     -->
#       </ul>
#      </div>
#     </div>
#     <div style="background:#FFFFFF url(https://slyvi-tstorage.s3.amazonaws.com/tli_1961376069377_dcf1c280c207f9019b69bfded20a4568e25812f8_1472022453932578.png); border-bottom:1px solid #e5e5e5; padding:15px; overflow:hidden">
#      <div class="pull-left" style="height:80px;">
#       <a class="aquila-logo" href="/">
#        <img src="https://slyvi-tstorage.s3.amazonaws.com/tli_1961376069377_6b8feca0d5f0aec7fb97ca58bed01e8e52a70179_1563400429756007.png" style="height:81px; margin-left:15px;"/>
#       </a>
#      </div>
#      <div class="pull-right logo-lega" style="height:80px;">
#       <a class="" href="http://www.legapallacanestro.com/" target="_blank">
#        <img src="https://slyvi-tstorage.s3.amazonaws.com/tli_1961376069377_6230266c34e01e1a058f49402e68dec68049a91f_156340077832614.png" style="height:40px; margin-left:15px; margin-top:20px"/>
#       </a>
#      </div>
#     </div>
#     <nav class="navbar navbar-default" role="navigation">
#      <!-- Brand and toggle get grouped for better mobile display -->
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-target=".navbar-ex1-collapse" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Menu
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <!--<a class="navbar-brand" href="/">Aquila basket Trento</a>-->
#      </div>
#      <!-- Collect the nav links, forms, and other content for toggling -->
#      <div class="collapse navbar-collapse navbar-ex1-collapse">
#       <ul class="menu nav navbar-nav menu-principale main-nav">
#        <li>
#         <a href="/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          Società
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/ochart/">
#            Organigramma
#           </a>
#          </li>
#          <li>
#           <a href="/page/341827768423">
#            Urania Basket Milano - la storia
#           </a>
#          </li>
#          <li>
#           <a href="/page/273108291687">
#            Basket Femminile Milano
#           </a>
#          </li>
#          <li>
#           <a href="/page/788504367207">
#            Privacy Urania Basket Milano
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="#">
#          Serie A2
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/groups/76460162706">
#            Staff
#           </a>
#          </li>
#          <li>
#           <a href="/groups/420057546386">
#            Roster
#           </a>
#          </li>
#          <li>
#           <a href="/events/1474993147282/?standings&amp;fixtures_and_results&amp;my_matches_only">
#            Campionato Serie A2
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="/news/">
#          News
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/news/category/346969318921">
#            Serie A2
#           </a>
#          </li>
#          <li>
#           <a href="/news/category/209530365449">
#            Programma Allenamenti
#           </a>
#          </li>
#          <li>
#           <a href="/news/category/72091411977">
#            News Settore Giovanile - Minibasket
#           </a>
#          </li>
#          <li>
#           <a href="#">
#            News Corsi scolastici
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="#">
#          Giovanili
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/page/243043520615">
#            Iscrizioni Settore Giovanile
#           </a>
#          </li>
#          <li>
#           <a href="/news/category/140810888713">
#            Interviste Atleti Urania
#           </a>
#          </li>
#          <li>
#           <a href="/groups/300335333010">
#            Staff Settore Giovanile
#           </a>
#          </li>
#          <li>
#           <a href="http://www.uraniabasket.it/page/311762997351">
#            Squadre Settore Giovanile
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="#">
#          Minibasket
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/page/685425152103">
#            Attività Sede e Orari
#           </a>
#          </li>
#          <li>
#           <a href="/page/792799334503">
#            Squadre Minibasket
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="#">
#          Scuole
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/news/category/415688795657">
#            News Corsi scolastici
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="/sponsors/">
#          Sponsor
#         </a>
#        </li>
#        <li>
#         <a href="#">
#          Multimedia
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/photos/">
#            Foto
#           </a>
#          </li>
#          <li>
#           <a href="/videos/">
#            Video
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="http://www.uraniabasket.it/ticketing">
#          Ticketing
#         </a>
#         <ul class="menu nav navbar-nav menu-principale">
#          <li>
#           <a href="/page/586640904295">
#            Accrediti
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <form action="search" class="navbar-form navbar-right search-bar">
#        <div class="form-group">
#         <input class="form-control" name="q" placeholder="Cerca" type="text"/>
#        </div>
#       </form>
#      </div>
#      <!-- /.navbar-collapse -->
#     </nav>
#    </header>
#    <div class="groove">
#     <div class="groove-left pull-left">
#     </div>
#     <div class="groove-right pull-right">
#     </div>
#     <div class="groove-center">
#     </div>
#    </div>
#    <div class="row inner-container">
#     <div class="col-md-8 col-sm-12">
#      <div class="content">
#       <p class="block-title">
#        Archivio news
#       </p>
#       <ul class="news">
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">
#            Buon Compleanno Wayne
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-26 10:51:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_511031137493_1603652138910135.png" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania">
#            Vittoria per la storia, 77-84 a Piacenza e Final8 per Urania
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-25 19:49:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Altra prova autoritaria di Urania che passa a Piacenza e timbra il pass, storico, che vale le F8 di Supercoppa. Gara dominata dai Wildcats che...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_98714277077_1603560156300233.png" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano">
#            Preview Piacenza - Milano
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-24 19:20:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Ultima giornata del girone di qualificazione di Supercoppa per Urania, i Wildcats cercano la qualificazione nella trasferta di domenica a Piacenza,...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_47174669525_1603470540764905.jpg" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre">
#            Programma allenamenti 26 ottobre - 1 novembre
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/209530365449/programma-allenamenti">
#            Programma Allenamenti
#           </a>
#           il 2020-10-23 17:58:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Dopo il nuovo DPCM del 25/10 rimaniamo in attesa di capire dalla FIP se è possibile proseguire nell'attività programmata oppure no....
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_390772053205_1603467395628656.jpg" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11">
#            La FIP di Roma posticipa l'inizio dei Campionati Giovanili al 29/11
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/72091411977/settore-giovanile-minibasket">
#            Settore Giovanile - Minibasket
#           </a>
#           il 2020-10-23 17:34:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Si riceve dalla FIP di Roma:
#
# Rinvio inizio Campionati regionali di ogni ordine e grado al 29 novembre 2020
# Il Consiglio Federale, preso atto degli...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/518866243078/lunedi-26-ottobre-si-torna-in-palestra-in-sicurezza">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_150253884629_1603466321767505.jpg" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/518866243078/lunedi-26-ottobre-si-torna-in-palestra-in-sicurezza">
#            Lunedì 26 ottobre si torna in palestra in sicurezza
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/72091411977/settore-giovanile-minibasket">
#            Settore Giovanile - Minibasket
#           </a>
#           il 2020-10-23 17:14:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Ci teniamo a comunicare ai nostri tesserati del Settore Giovanile e alle relative famiglie che nella giornata giovedì 22/10, sentito il...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/106549382662/sentite-condoglianze">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_17109898453_1599235578743402.jpg" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/106549382662/sentite-condoglianze">
#            Sentite Condoglianze
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-19 17:21:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Urania si stringe con un grande abbraccio attorno alla famiglia Biganzoli, per la triste scomparsa di Felice Pirola.
# Alla figlia Stefania,...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/381427289606/urania-da-applausi-i-wildcats-stendono-treviglio-85-58">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_425131791573_1603044561114009.png" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/381427289606/urania-da-applausi-i-wildcats-stendono-treviglio-85-58">
#            Urania da applausi, i WIldcats stendono Treviglio, 85-58
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-18 20:05:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Splendida prova corale di Urania che stende Treviglio (85-58) ed intasca il secondo successo in Supercoppa.  Scappa via già nel primo...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/175268859398/la-preview-di-urania-treviglio">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_12814931157_1602960107887668.png" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/175268859398/la-preview-di-urania-treviglio">
#            La Preview di Urania - Treviglio
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#            Serie A2
#           </a>
#           il 2020-10-17 20:40:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           Dopo la bella vittoria esterna a Bergamo la scorsa settimana arriva l’esordio casalingo in Supercoppa per i Wildcats. Urania che ospita al...
#          </p>
#         </div>
#        </li>
#        <li class="row">
#         <div class="col-sm-4 col-md-4 nopadding news-thumb">
#          <a href="http://www.uraniabasket.it/news/450146766342/programma-allenamenti-19-25-ottobre">
#           <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_218973361365_1602861112675262.jpg" style="background-color:#eee;"/>
#          </a>
#         </div>
#         <div class="col-sm-8 col-md-8 news-inner">
#          <h3 style="margin-top:5px">
#           <a href="http://www.uraniabasket.it/news/450146766342/programma-allenamenti-19-25-ottobre">
#            Programma allenamenti 19-25 ottobre
#           </a>
#          </h3>
#          <p class="news-info">
#           Pubblicata in
#           <a class="category-link" href="http://www.uraniabasket.it/news/categories/209530365449/programma-allenamenti">
#            Programma Allenamenti
#           </a>
#           il 2020-10-16 16:49:00
#          </p>
#          <h4>
#          </h4>
#          <p>
#           In attesa di notizie più precise rispetto a indiscrezione di stampa QUI, siamo pronti a pubblicare il programma allenamenti per le squadre del...
#          </p>
#         </div>
#        </li>
#       </ul>
#       <div class="pagination-box" style="text-align:center">
#        <ul class="pagination pagination-lg pagination-centered">
#         <li>
#          <a href="#">
#           «
#          </a>
#         </li>
#         <li class="active">
#          <a href="#">
#           1
#          </a>
#         </li>
#         <li>
#          <a href="?page=2">
#           2
#          </a>
#         </li>
#         <li>
#          <a href="?page=3">
#           3
#          </a>
#         </li>
#         <li>
#          <a href="?page=4">
#           4
#          </a>
#         </li>
#         <li>
#          <a href="?page=5">
#           5
#          </a>
#         </li>
#         <li>
#          <a href="?page=6">
#           6
#          </a>
#         </li>
#         <li>
#          <a href="?page=2">
#           «
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="col-md-4 col-sm-12">
#      <div class="sidebar">
#       <div class="slywdg-box slywdg-event-nmwl">
#        <h3 class="slywdg-title">
#         <a href="/events/1474993147282/?standings&amp;fixtures_and_results">
#          Prossima partita
#         </a>
#        </h3>
#        <div class="row slywdg-div-event match">
#         <div class="col-md-5 col-xs-5">
#          <div class="team-logo">
#           <img alt="" class="img-responsive" src=""/>
#          </div>
#          <p class="team-name">
#          </p>
#          <p class="team-name">
#          </p>
#         </div>
#         <div class="col-md-2 col-xs-2 vs">
#          vs
#         </div>
#         <div class="col-md-5 col-xs-5">
#          <div class="team-logo">
#           <img alt="" class="img-responsive" src=""/>
#          </div>
#          <p class="team-name">
#          </p>
#          <p class="team-name">
#          </p>
#         </div>
#        </div>
#        <p class="match-date">
#         26/10/2020 12:20
#        </p>
#       </div>
#       <div class="slywdg-box">
#        <h3 class="menu_sidebar slywdg-title">
#         <a href="/news">
#          Ultime news
#         </a>
#        </h3>
#        <div class="slywdg-div-latest-news">
#         <div class="media">
#          <a class="pull-left slywdg-div-latest-news-img" href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne" style="background-image: url(https://slyvi-tstorage.fra1.digitaloceanspaces.com/t0_tml1961376069377_236153230549_1603705960744424.png);">
#          </a>
#          <div class="media-body">
#           <h3 class="media-heading">
#            <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">
#             Buon Compleanno Wayne
#            </a>
#           </h3>
#           <span class="news-body-preview">
#            Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy...
#           </span>
#          </div>
#         </div>
#         <div class="media">
#          <a class="pull-left slywdg-div-latest-news-img" href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania" style="background-image: url(https://slyvi-tstorage.fra1.digitaloceanspaces.com/t0_tml1961376069377_511031137493_1603652138910135.png);">
#          </a>
#          <div class="media-body">
#           <h3 class="media-heading">
#            <a href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania">
#             Vittoria per la storia, 77-84 a Piacenza e Final8 per Urania
#            </a>
#           </h3>
#           <span class="news-body-preview">
#            Altra prova autoritaria di Urania che passa a Piacenza e timbra il pass, storico,...
#           </span>
#          </div>
#         </div>
#         <div class="media">
#          <a class="pull-left slywdg-div-latest-news-img" href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano" style="background-image: url(https://slyvi-tstorage.fra1.digitaloceanspaces.com/t0_tml1961376069377_98714277077_1603560156300233.png);">
#          </a>
#          <div class="media-body">
#           <h3 class="media-heading">
#            <a href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano">
#             Preview Piacenza - Milano
#            </a>
#           </h3>
#           <span class="news-body-preview">
#            Ultima giornata del girone di qualificazione di Supercoppa per Urania, i Wildcats...
#           </span>
#          </div>
#         </div>
#         <div class="media">
#          <a class="pull-left slywdg-div-latest-news-img" href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre" style="background-image: url(https://slyvi-tstorage.fra1.digitaloceanspaces.com/t0_tml1961376069377_47174669525_1603470540764905.jpg);">
#          </a>
#          <div class="media-body">
#           <h3 class="media-heading">
#            <a href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre">
#             Programma allenamenti 26 ottobre - 1 novembre
#            </a>
#           </h3>
#           <span class="news-body-preview">
#            Dopo il nuovo DPCM del 25/10 rimaniamo in attesa di capire dalla FIP se è...
#           </span>
#          </div>
#         </div>
#         <div class="media">
#          <a class="pull-left slywdg-div-latest-news-img" href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11" style="background-image: url(https://slyvi-tstorage.fra1.digitaloceanspaces.com/t0_tml1961376069377_390772053205_1603467395628656.jpg);">
#          </a>
#          <div class="media-body">
#           <h3 class="media-heading">
#            <a href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11">
#             La FIP di Roma posticipa l'inizio dei Campionati Giovanili al 29/11
#            </a>
#           </h3>
#           <span class="news-body-preview">
#            Si riceve dalla FIP di Roma:
#
# Rinvio inizio Campionati regionali di ogni ordine e...
#           </span>
#          </div>
#         </div>
#        </div>
#       </div>
#       <!--        <div class="next-last-matches col-md-12 col-sm-6">
#               <h3 class="box-title">Partite</h3>
#
#               <div class="last-match next-match">
#                 {block:Event eventID={event:hpevent}}
#                 {block:MatchDetails matchID=next}
#                 <div class="match">
#                   <div class="match-bg">
#                     <div class="logo-home"><img src="{ParticipantA-Logo-M}" class="img-responsive" alt="{ParticipantA}" width="100" /></div>
#                     <div class="logo-visitor"><img src="{ParticipantB-Logo-M}" class="img-responsive" alt="{ParticipantB}" width="100" /></div>
#                     <p>vs</p>
#                   </div><!-- FINE .match-bg --
#                   <div class="teams">
#                     <div class="team-home">
#                       <p class="name">{ParticipantA}</p>
#                     </div>
#                     <div class="team-visitor">
#                       <p class="name">{ParticipantB}</p>
#                     </div>
#                   </div>
#                   <p class="match-date">{Date}</p>
#                 </div>
#                 <div class="match-links" style="border:none">
#                   <div class="row">
#                     <div class="col-md-12"><a href="http://aquilabasket.slyvi.com/page/135669338215/biglietti">Biglietti</a></div>
#                   </div>
#                 </div>
#                 {/block:MatchDetails}
#                 {/block:Event}
#               </div>
#               <div class="last-match" style="border-top:1px solid #0080c8;padding-top:15px">
#                 {block:Event eventID={event:hpevent}}
#                 {block:MatchDetails matchID=previous}
#                 <div class="match">
#                   <div class="match-bg">
#                     <div class="logo-home"><img src="{ParticipantA-Logo-M}" class="img-responsive" alt="{ParticipantA}" width="80" /></div>
#                     <div class="logo-visitor"><img src="{ParticipantB-Logo-M}" class="img-responsive" alt="{ParticipantB}" width="80" /></div>
#                     <p>vs</p>
#                   </div><!-- FINE .match-bg --
#                   <div class="teams">
#                     <div class="team-home">
#                       <p class="name">{ParticipantA}</p>
#                       <p class="result">{ResultA}</p>
#                     </div>
#                     <div class="team-visitor">
#                       <p class="name">{ParticipantB}</p>
#                       <p class="result">{ResultB}</p>
#                     </div>
#                   </div>
#                   <p class="match-date">{Date}</p>
#                 </div>
#                 {/block:MatchDetails}
#                 {/block:Event}
#               </div>
#             </div> -->
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="container">
#     <div class="footer-boxes">
#      <div class="row">
#       <div class="col-md-8 col-sm-8 events-photos">
#        <h3 class="box-title">
#         <a href="/photos">
#          Ultime foto
#         </a>
#        </h3>
#        <div class="row">
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_403120084181_1583744107736129.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_162601915605_1583744104407961.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_437479822549_1583744101406718.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_25162962133_1583744097463911.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_300040869077_1583744093576574.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_231321392341_1583744090387798.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_506199299285_1583744086390894.jpg);">
#          </a>
#         </div>
#         <div class="col-xs-3 col-md-3 col-sm-3">
#          <a class="thumbnail" href="http://www.uraniabasket.it/photos/album/147776989949/urania-milano-sporting-club-juve-caserta" style="background-image: url(https://slyvi-tphotos.s3.amazonaws.com/m0_pht1961376069377_93882438869_1583744082402441.jpg);">
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4 col-sm-4 last-video">
#        <h3 class="box-title">
#         <a href="videos">
#          Video
#         </a>
#        </h3>
#        <div class="row">
#         <div class="col-md-12">
#          <a class="thumbnail thumb-video" href="http://www.uraniabasket.it/videos/222888765785" style="background-image: url(http://i.ytimg.com/vi/3bcRTZi5XcE/hqdefault.jpg);">
#           <span class="play-icon">
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="real-footer">
#     <div class="container">
#      <div class="row">
#       <div class="col-md-8 col-sm-12 copy left-footer">
#        <div>
#         <img alt="" class="visible-md visible-lg" src="https://slyvi-tstorage.s3.amazonaws.com/tli_1961376069377_6b8feca0d5f0aec7fb97ca58bed01e8e52a70179_1563400429756007.png"/>
#        </div>
#        <div style="clear:both">
#         <div class="slywdg-box slywdg-customhtml">
#          <p>
#           SSDaRL Urania Basket Milano
#           <br/>
#           Viale Cirene, 9 20135 Milano
#           <br/>
#           P.Iva 09445070155
#           <br/>
#           Tel.: 02.7384056
#           <br/>
#           Foto di Stefano Gariboldi
#          </p>
#         </div>
#        </div>
#       </div>
#       <div class="col-md-4 col-sm-12 slyvi">
#        <p class="powered">
#         Powered by
#         <a href="http://www.slyvi.com">
#          SLYVI.
#         </a>
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <!-- Include all compiled plugins (below), or include individual files as needed -->
#   <script crossorigin="anonymous" integrity="sha256-wS9gmOZBqsqWxgIVgA8Y9WcQOa7PgSIX+rPA0VL2rbQ=" src="https://code.jquery.com/jquery-1.9.1.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js">
#   </script>
#   <script src="https://cdn.jsdelivr.net/jquery.mcustomscrollbar/3.1.5/jquery.mCustomScrollbar.concat.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/bxslider/4.2.5/jquery.bxslider.min.js" type="text/javascript">
#   </script>
#   <script src="/js/jquery-mobile-custom-min.js" type="text/javascript">
#   </script>
#   <script src="/js/base.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-cookie/1.4.1/jquery.cookie.min.js">
#   </script>
#   <script src="//www.slyvi.com/assets/js/view.js?auto" type="text/javascript">
#   </script>
#   <script>
#    $(window).load(function() {
#     $('.carousel').carousel();
#      $("#home-carousel").swiperight(function() {
#           $(this).carousel('prev');
#             });
#        $("#home-carousel").swipeleft(function() {
#           $(this).carousel('next');
#    });
#    $(".scroller").mCustomScrollbar({
#         scrollInertia:0
#     });
#    $('.sponsors-carousel').bxSlider({
#         auto: true,
#         minSlides: 2,
#         maxSlides: 8,
#         //slideWidth: 125,
#        // slideMargin: 10
#     });
#
# });
#   </script>
#   <script src="//platform.twitter.com/widgets.js" type="text/javascript">
#   </script>
#   <script src="//www.slyvi.com/js/jquery.team_behavior.js?19032018" type="text/javascript">
#   </script>
#   <script src="https://slyvi-cdn.ams3.digitaloceanspaces.com/assets/js/ads.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    if(document.getElementById("awjlJPnQbmYZ")){
# 													awjlJPnQbmYZ="No";
# 												} else {
# 													awjlJPnQbmYZ="Yes";
#
# 												}
# 												if(typeof ga !== "undefined"){
# 													ga("send","event","Blocking Ads",awjlJPnQbmYZ,{"nonInteraction":1});
# 												} else if(typeof _gaq !== "undefined"){
# 													_gaq.push(["_trackEvent","Blocking Ads",awjlJPnQbmYZ,undefined,undefined,true]);
# 												}
# 												if(typeof _paq !== "undefined"){
# 													_paq.push(["trackEvent","Blocking Ads",awjlJPnQbmYZ]);
# 												}
#   </script>
#  </body>
# </html>

# %% [markdown]
# Let's start by grabbing the first article. Let's visit the web page http://www.uraniabasket.it/news, go with the cursor over the title of the first news, right click with the mouse and select inspect element. Now we look for the container of the first news. In this case we can see that `<li class="row">` contains what we want.
#
# <img src="fig/fig1.png" width="600">
#
# We can see also that what we want is inside the `<ul class="news">`. We can use a filter to create a soup that contains just the news. This is important since in our case we have `<li class="row">` also in the header of the website.

# %%
all_news_filter = {'class': 'news'}
all_news = soup.find('ul', all_news_filter)
news = all_news.find('li')
print(news.prettify())
# Out:
# <li class="row">
#  <div class="col-sm-4 col-md-4 nopadding news-thumb">
#   <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">
#    <img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png" style="background-color:#eee;"/>
#   </a>
#  </div>
#  <div class="col-sm-8 col-md-8 news-inner">
#   <h3 style="margin-top:5px">
#    <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">
#     Buon Compleanno Wayne
#    </a>
#   </h3>
#   <p class="news-info">
#    Pubblicata in
#    <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">
#     Serie A2
#    </a>
#    il 2020-10-26 10:51:00
#   </p>
#   <h4>
#   </h4>
#   <p>
#    Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...
#   </p>
#  </div>
# </li>

# %% [markdown]
# Perfect, we get all the html for the first article. We can see from the output of the previous cell that all the information we need, except for the image, are inside the `<div class="col-sm-8 col-md-8 news-inner">`. So, we can filter for this specific `div`-`class` combination.

# %%
info_filter = {"class": "col-sm-8 col-md-8 news-inner"}
info_news = news.find('div', info_filter)
print(info_news)
# Out:
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">Buon Compleanno Wayne</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-26 10:51:00</p>
# <h4></h4>
# <p>Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...</p>
# </div>

# %% [markdown]
# Now we can grab the title and the link:

# %%
title = info_news.find('h3').a.text
link = info_news.find('h3').a['href']
print(title)
print(link)
# Out:
# Buon Compleanno Wayne
# http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne

# %% [markdown]
# Perfect! For the date and the summary, we can see that they are inside two different paragraph `<p>`. We can get both using the method find_all and then access each of them with the respective position. The date will be in position 0 and the summary in the position 1.

# %%
paragraph = info_news.find_all('p')
date_ = paragraph[0].text
summary = paragraph[1].text
print(date_)
print(summary)
# Out:
# Pubblicata in Serie A2 il 2020-10-26 10:51:00
# Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...

# %% [markdown]
# Ok, we are almost done but we can see that the date variable date contains also unrelevant info. We can use a simple regex to grab just the date.

# %%
date = re.findall('\d{4}-\d{1,2}-\d{1,2}', date_)[0]

# %% [markdown]
# The pattern we used is very simple; it search for a digit __\d__ repeated exactly 4 times __{4}__ (the year) follewed by an hypen, followed by a digit repeated from 1 to 2 times __{1,2}__ (month) followed again by an hypen and a digit repeated 1 or 2 times.
#
# Now we have exactly what wee need except for the url of the thumbnail in case there is. Let's print the news html to see where it is positioned.

# %%
news
# Out:
# <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">Buon Compleanno Wayne</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-26 10:51:00</p>
# <h4></h4>
# <p>Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...</p>
# </div>
# </li>

# %% [markdown]
# We can access to it with news.a.img and asking for the url as in a dictionary. Remember that we are looking for a thumbnail IF ANY, so we must be sure that in case there is no any image for the current news the code does not break. We can bypass this problem with __try__:

# %%
try:
    url_thumbnail = news.a.img['src']
    print(url_thumbnail)
except:
    'Thumbnail not present'
# Out:
# https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png

# %% [markdown]
# Now we have all that we need! Let's print all the info that we want to store:

# %%
print(title)
print(link)
print(date)
print(summary)
print(url_thumbnail)
# Out:
# Buon Compleanno Wayne
# http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne
# 2020-10-26
# Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...
# https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png

# %% [markdown]
# Great! Now we see how to scrap the information for a single news but how we can get the same info for all the news? Instead of using the method __find__ we need __find_all__.

# %%
all_news_filter = {'class': 'news'}
all_news = soup.find('ul', all_news_filter)
news = all_news.find_all('li')
print(news)
# Out:
# [<li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">Buon Compleanno Wayne</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-26 10:51:00</p>
# <h4></h4>
# <p>Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_511031137493_1603652138910135.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/441556831750/vittoria-per-la-storia-77-84-a-piacenza-e-final8-per-urania">Vittoria per la storia, 77-84 a Piacenza e Final8 per Urania</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-25 19:49:00</p>
# <h4></h4>
# <p>Altra prova autoritaria di Urania che passa a Piacenza e timbra il pass, storico, che vale le F8 di Supercoppa. Gara dominata dai Wildcats che...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_98714277077_1603560156300233.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/29239971334/preview-piacenza-milano">Preview Piacenza - Milano</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-24 19:20:00</p>
# <h4></h4>
# <p>Ultima giornata del girone di qualificazione di Supercoppa per Urania, i Wildcats cercano la qualificazione nella trasferta di domenica a Piacenza,...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_47174669525_1603470540764905.jpg" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/304117878278/programma-allenamenti-26-ottobre-1-novembre">Programma allenamenti 26 ottobre - 1 novembre</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/209530365449/programma-allenamenti">Programma Allenamenti</a> il 2020-10-23 17:58:00</p>
# <h4></h4>
# <p>Dopo il nuovo DPCM del 25/10 rimaniamo in attesa di capire dalla FIP se è possibile proseguire nell'attività programmata oppure no....</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_390772053205_1603467395628656.jpg" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/243988336134/la-fip-di-roma-posticipa-l-inizio-dei-campionati-giovanili-al-29-11">La FIP di Roma posticipa l'inizio dei Campionati Giovanili al 29/11</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/72091411977/settore-giovanile-minibasket">Settore Giovanile - Minibasket</a> il 2020-10-23 17:34:00</p>
# <h4></h4>
# <p>Si riceve dalla FIP di Roma:
#
# Rinvio inizio Campionati regionali di ogni ordine e grado al 29 novembre 2020
# Il Consiglio Federale, preso atto degli...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/518866243078/lunedi-26-ottobre-si-torna-in-palestra-in-sicurezza"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_150253884629_1603466321767505.jpg" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/518866243078/lunedi-26-ottobre-si-torna-in-palestra-in-sicurezza">Lunedì 26 ottobre si torna in palestra in sicurezza</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/72091411977/settore-giovanile-minibasket">Settore Giovanile - Minibasket</a> il 2020-10-23 17:14:00</p>
# <h4></h4>
# <p>Ci teniamo a comunicare ai nostri tesserati del Settore Giovanile e alle relative famiglie che nella giornata giovedì 22/10, sentito il...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/106549382662/sentite-condoglianze"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_17109898453_1599235578743402.jpg" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/106549382662/sentite-condoglianze">Sentite Condoglianze</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-19 17:21:00</p>
# <h4></h4>
# <p>Urania si stringe con un grande abbraccio attorno alla famiglia Biganzoli, per la triste scomparsa di Felice Pirola.
# Alla figlia Stefania,...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/381427289606/urania-da-applausi-i-wildcats-stendono-treviglio-85-58"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_425131791573_1603044561114009.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/381427289606/urania-da-applausi-i-wildcats-stendono-treviglio-85-58">Urania da applausi, i WIldcats stendono Treviglio, 85-58</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-18 20:05:00</p>
# <h4></h4>
# <p>Splendida prova corale di Urania che stende Treviglio (85-58) ed intasca il secondo successo in Supercoppa.  Scappa via già nel primo...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/175268859398/la-preview-di-urania-treviglio"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_12814931157_1602960107887668.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/175268859398/la-preview-di-urania-treviglio">La Preview di Urania - Treviglio</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-17 20:40:00</p>
# <h4></h4>
# <p>Dopo la bella vittoria esterna a Bergamo la scorsa settimana arriva l’esordio casalingo in Supercoppa per i Wildcats. Urania che ospita al...</p>
# </div>
# </li>, <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/450146766342/programma-allenamenti-19-25-ottobre"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_218973361365_1602861112675262.jpg" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/450146766342/programma-allenamenti-19-25-ottobre">Programma allenamenti 19-25 ottobre</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/209530365449/programma-allenamenti">Programma Allenamenti</a> il 2020-10-16 16:49:00</p>
# <h4></h4>
# <p>In attesa di notizie più precise rispetto a indiscrezione di stampa QUI, siamo pronti a pubblicare il programma allenamenti per le squadre del...</p>
# </div>
# </li>]

# %% [markdown]
# Now the variable news contains all the news of the current page and we can acces them with the corresponding position inside the list.
#
# The number of news in the current page is:

# %%
print(len(news))
# Out:
# 10

# %% [markdown]
# We can see that the news that we scrap before is in the first position.

# %%
print(news[0])
# Out:
# <li class="row">
# <div class="col-sm-4 col-md-4 nopadding news-thumb">
# <a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne"><img class="img-responsive" src="https://slyvi-tstorage.fra1.digitaloceanspaces.com/m0_tml1961376069377_236153230549_1603705960744424.png" style="background-color:#eee;"/></a>
# </div>
# <div class="col-sm-8 col-md-8 news-inner">
# <h3 style="margin-top:5px"><a href="http://www.uraniabasket.it/news/166678924806/buon-compleanno-wayne">Buon Compleanno Wayne</a></h3>
# <p class="news-info">Pubblicata in <a class="category-link" href="http://www.uraniabasket.it/news/categories/346969318921/serie-a2">Serie A2</a> il 2020-10-26 10:51:00</p>
# <h4></h4>
# <p>Urania Basket Milano augura un felice e sereno Compleanno a Wayne Langston!
#
# Happy Birthday Lefty...</p>
# </div>
# </li>

# %% [markdown]
# To scrap for the news in all the pages we can simply modify the url of the page to change iteratively the page number. Before doing so we need to create a dataframe to store the information for all the news.

# %%
columns_name = ['Title', 'Link', 'Date', 'Summary', 'Thumbnail']
news_df = pd.DataFrame(columns=columns_name)

# %% [markdown]
# Now we can loop over all the news inside all the pages. In doing so, we will use a while loop until the loop flag becomes `False`. By inspecting the website, we can see that all the pages have the same number of news except from the last one. So, we can change the flag loop to False when the actual news length is different from the one of the previous page.

# %%
# Specify the URL with page number as a variable
url = 'http://www.uraniabasket.it/news?page={number}'

number = 1  # initial page number

loop = True  # initialization for starting loop

# While loop to go through all the news pages
while loop:
    # Send a get request to the website and get the text from the response
    response = requests.get(url.format(number=number)).text

    # Parse HTML document
    soup = BeautifulSoup(response, "html.parser")

    # Search for all the first tag <ul> with attribute 'news'
    all_news_filter = {'class': 'news'}
    all_news = soup.find('ul', all_news_filter)

    # Search for all the news to get the total number of the current page
    news = all_news.find_all('li')
    news_number = len(news)  # number of news in current page

    # Loop over all the news inside the current page:
    for n in range(news_number):
        curr_news = news[n]

        # Get information from tag <div> with attribute 'col-sm-8 col-md-8 news-inner'
        info_filter = {"class": "col-sm-8 col-md-8 news-inner"}
        info_news = curr_news.find('div', info_filter)

        # Grab title
        title = info_news.find('h3').a.text

        # Grab link
        link = info_news.find('h3').a['href']

        # Find all paragraphs
        paragraph = info_news.find_all('p')

        # Grab date. We use regex to clean for irrelevant text
        date_ = paragraph[0].text
        date = re.findall('\d{4}-\d{1,2}-\d{1,2}', date_)[0]

        # Grab summary
        summary = paragraph[1].text

        # Grab thumbnail if any
        try:
            url_thumbnail = curr_news.a.img['src']
        except:
            url_thumbnail = ''
            'Thumbnail not present'

        # Update DataFrame with current news
        news_df = news_df.append(pd.DataFrame([[title, link, date, summary, url_thumbnail]],
                                              columns=columns_name), ignore_index=True)
    # Check if current page is last page
    if number > 1:
        if news_number != old_news_number:
            loop = False

    number += 1  # new page
    old_news_number = news_number

# %%
news_df
# Out:
#                                                  Title  \
# 0                                Buon Compleanno Wayne
# 1    Vittoria per la storia, 77-84 a Piacenza e Fin...
# 2                            Preview Piacenza - Milano
# 3        Programma allenamenti 26 ottobre - 1 novembre
# 4    La FIP di Roma posticipa l'inizio dei Campiona...
# ..                                                 ...
# 346  Under 14 Elite: ABA Legnano - Urania Milano 74-68
# 347  Under 16 Eccellenza: Urania Milano - Bernaregg...
# 348  Under 13 Regionale: Trezzano Basket - Urania E...
# 349    Under 13 Top: Urania Milano - EA7 Olimpia 38-90
# 350  Allianz Cloud ancora tabù per i Wildcats, Ferr...
#
#                                                   Link        Date  \
# 0    http://www.uraniabasket.it/news/166678924806/b...  2020-10-26
# 1    http://www.uraniabasket.it/news/441556831750/v...  2020-10-25
# 2    http://www.uraniabasket.it/news/29239971334/pr...  2020-10-24
# 3    http://www.uraniabasket.it/news/304117878278/p...  2020-10-23
# 4    http://www.uraniabasket.it/news/243988336134/l...  2020-10-23
# ..                                                 ...         ...
# 346  http://www.uraniabasket.it/news/160773344774/u...  2019-10-27
# 347  http://www.uraniabasket.it/news/435651251718/u...  2019-10-27
# 348  http://www.uraniabasket.it/news/23334391302/un...  2019-10-27
# 349  http://www.uraniabasket.it/news/298212298246/u...  2019-10-27
# 350  http://www.uraniabasket.it/news/250967657990/a...  2019-10-26
#
#                                                Summary  \
# 0    Urania Basket Milano augura un felice e sereno...
# 1    Altra prova autoritaria di Urania che passa a ...
# 2    Ultima giornata del girone di qualificazione d...
# 3    Dopo il nuovo DPCM del 25/10 rimaniamo in atte...
# 4    Si riceve dalla FIP di Roma:\n\nRinvio inizio ...
# ..                                                 ...
# 346  Campionato Under 14 Elite - 4° giornata di and...
# 347  Campionato Under 16 Eccellenza - 3° giornata d...
# 348  Campionato Under 13 Regionale - 3° giornata gi...
# 349  Campionato Under 13 Top - 3° giornata di andat...
# 350  Altra dolorosa sconfitta in volata per l’Urani...
#
#                                              Thumbnail
# 0    https://slyvi-tstorage.fra1.digitaloceanspaces...
# 1    https://slyvi-tstorage.fra1.digitaloceanspaces...
# 2    https://slyvi-tstorage.fra1.digitaloceanspaces...
# 3    https://slyvi-tstorage.fra1.digitaloceanspaces...
# 4    https://slyvi-tstorage.fra1.digitaloceanspaces...
# ..                                                 ...
# 346  https://slyvi-tstorage.fra1.digitaloceanspaces...
# 347  https://slyvi-tstorage.fra1.digitaloceanspaces...
# 348  https://slyvi-tstorage.fra1.digitaloceanspaces...
# 349  https://slyvi-tstorage.fra1.digitaloceanspaces...
# 350  https://slyvi-tstorage.fra1.digitaloceanspaces...
#
# [351 rows x 5 columns]

# %% [markdown]
# We did it! As we can see the last news in the DataFrame is _Allianz Cloud ancora tabù per i Wildcats, Ferrara beffa l’Urania 71-72_ which is exactly the last news of the website at the page 36.
#
# N.B. News are continually updated so at the time you are reading this notebook the last news or the total number of pages can be different.
